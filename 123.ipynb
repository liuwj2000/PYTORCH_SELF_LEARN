# %% [markdown]
# # 批标准化

# %% [markdown]
# ![1563838579%281%29.png](attachment:1563838579%281%29.png)
# 常用的方法就是中心化+标准化。
#
# 中心化即修改数据的中心位置（每个特征维度上减去对应的均值，以得到0均值的特征）
#
# 标准化也很简单，在数据变成0均值后，为了使得不同的特征维度有相同的规模，可以除标准差，来近似一个标准正态分布
#
# 批标准化要对每一层网络的输出做一个归一化，让他服从标准正态分布，这样后一层网络的输入也是标准正态分布，这样就能够较好地进行训练，加快收敛速度
